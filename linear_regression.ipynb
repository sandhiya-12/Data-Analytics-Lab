# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("E:\\7th sem\\DA lab\\train.csv")
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
from scipy import stats
import matplotlib.pyplot as plt

# %%
dat=pd.read_csv("C:\\Users\\Sandy\\Downloads\\train.csv")
df=pd.DataFrame(dat)

# %%
sample_data={'ApplicantIncome':np.random.rand(20),
      'LoanAmount': np.random.rand(20)}

# %%
df1= pd.DataFrame(sample_data)

# %%
df1.plot.scatter(x='ApplicantIncome', y='LoanAmount', s=np.pi*3, c='Red')

# %%
X = pd.DataFrame(df['LoanAmount'])

# %%
Y = pd.DataFrame(df['ApplicantIncome'])

# %%
model = LinearRegression()
scores = []

# %%
linear_model=LinearRegression().fit(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-fc50a68bf5ef> in <module>
# ----> 1 linear_model=LinearRegression().fit(X,Y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
 from sklearn.linear_model import LinearRegression

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
X = pd.DataFrame(df['LoanAmount'])

# %%
Y = pd.DataFrame(df['ApplicantIncome'])

# %%
linear_model=LinearRegression().fit(X,Y)

# %%
linear_model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
linear_model.score(X,Y)
# Out:
# 0.3199265010171849

# %%
plt.scatter(X, Y,  color='black')

# %%
plt.scatter(X, Y, s=np.pi*3, color='black')
plt.plot(X, linear_model.predict(X), color='blue', linewidth=2)
plt.xticks(())
plt.yticks(())
plt.show()

# %%
X1 = X.sample(frac=0.3)
print(X1)
# Out:
#      LoanAmount
# 121   44.000000
# 196  187.000000
# 194  120.000000
# 5    267.000000
# 352   95.000000
# 403   53.000000
# 221  116.000000
# 414  178.000000
# 191  164.000000
# 84    50.000000
# 171  700.000000
# 312   56.000000
# 26   122.000000
# 293  143.000000
# 264  128.000000
# 350  228.000000
# 240  120.000000
# 420  138.000000
# 41    47.000000
# 17    76.000000
# 425  121.000000
# 463  132.000000
# 524  146.412162
# 263  120.000000
# 493  225.000000
# 563  132.000000
# 83   265.000000
# 98   115.000000
# 159  255.000000
# 475  150.000000
# ..          ...
# 76   176.000000
# 36   100.000000
# 295  110.000000
# 453   90.000000
# 522  100.000000
# 222  144.000000
# 539  157.000000
# 112  152.000000
# 239   96.000000
# 329   67.000000
# 145  100.000000
# 0    146.412162
# 316  120.000000
# 364  141.000000
# 585  172.000000
# 609   71.000000
# 232  120.000000
# 261  134.000000
# 533  196.000000
# 378   71.000000
# 33   114.000000
# 601  155.000000
# 127  146.412162
# ...

# %%
Y1 = Y.sample(n=184)
print(Y1)
# Out:
#      ApplicantIncome
# 121             4166
# 225             3250
# 248             2882
# 250             1668
# 456             4301
# 277             3103
# 185            39147
# 443            37719
# 244             3406
# 60              2500
# 111             2929
# 509            13262
# 409            81000
# 119            10408
# 62              2609
# 263             7200
# 273             2620
# 210            10000
# 408             8300
# 547             2526
# 385             3667
# 170             1820
# 51              3086
# 317             2058
# 239             3315
# 113             7451
# 529             6783
# 329             2500
# 10              3200
# 269             2876
# ..               ...
# 414             2149
# 323             3166
# 450             2309
# 209             3418
# 41              1800
# 301             2875
# 518             4683
# 35              2275
# 298             5000
# 343             3173
# 100             4288
# ...

# %%
plt.scatter(X1, Y1, s=np.pi*3, color='black')
plt.plot(X1, linear_model.predict(X1), color='blue', linewidth=2)
plt.xlabel("Loan Amount")
plt.ylabel("Applicant Income")
plt.show()

# %%
linear_model.predict(X1)
# Out:
# array([[ 1192.54138622],
#        [ 7072.32408568],
#        [ 4317.46086285],
#        [10361.71300845],
#        [ 3289.52682449],
#        [ 1562.59764003],
#        [ 4152.99141671],
#        [ 6702.26783187],
#        [ 6126.62477038],
#        [ 1439.24555542],
#        [28165.53055298],
#        [ 1685.94972463],
#        [ 4399.69558592],
#        [ 5263.16017815],
#        [ 4646.39975513],
#        [ 8758.1359086 ],
#        [ 4317.46086285],
#        [ 5057.57337048],
#        [ 1315.89347082],
#        [ 2508.29695533],
#        [ 4358.57822439],
#        [ 4810.86920127],
#        [ 5403.45928339],
#        [ 4317.46086285],
#        [ 8634.783824  ],
#        [ 4810.86920127],
#        [10279.47828538],
#        [ 4111.87405518],
#        [ 9868.30467004],
#        [ 5550.98170889],
#        [ 2138.24070151],
#        [ 2261.59278612],
#        [19119.71101535],
#        [ 6373.32893959],
#        [ 4523.04767053],
#        [ 6208.85949345],
#        [ 3207.29210142],
# ...
